# %% [markdown]
# # GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import pandas as pd
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()
diabetes

# %%
alpha = [0.001, 0.01, 0.05, 0.1, 0.15, 1, 10]
param_grid = dict(alpha=alpha)

gs = GridSearchCV(estimator=Ridge(), param_grid=param_grid, cv=10)
result = gs.fit(diabetes.data, diabetes.target)

print("최적 점수 : {}".format(result.best_score_))
print("최적 파라미터 : {}".format(result.best_params_))
print(gs.best_estimator_)
pd.DataFrame(result.cv_results_)
# Out:
# 최적 점수 : 0.4634759226552429
# 최적 파라미터 : {'alpha': 0.05}
# Ridge(alpha=0.05)
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.002152      0.002214         0.000500        0.000500       0.001
# 1       0.000500      0.000500         0.000100        0.000300        0.01
# 2       0.000899      0.000300         0.000000        0.000000        0.05
# 3       0.000300      0.000458         0.000099        0.000298         0.1
# 4       0.000500      0.000500         0.000200        0.000400        0.15
# 5       0.000400      0.000490         0.000000        0.000000           1
# 6       0.000500      0.000500         0.000500        0.000500          10
#
#              params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.001}           0.554415           0.233686           0.356799
# 1   {'alpha': 0.01}           0.546297           0.244132           0.368901
# 2   {'alpha': 0.05}           0.535328           0.247669           0.379245
# 3    {'alpha': 0.1}           0.526550           0.244987           0.383530
# 4   {'alpha': 0.15}           0.518515           0.241118           0.385578
# 5      {'alpha': 1}           0.421593           0.168442           0.358004
# 6     {'alpha': 10}           0.159386          -0.081177           0.152190
#
#    split3_test_score  split4_test_score  split5_test_score  split6_test_score  \
# 0           0.620259           0.267033           0.619397           0.419907
# 1           0.613732           0.271717           0.623089           0.426074
# 2           0.609255           0.279766           0.622258           0.430250
# 3           0.606594           0.286094           0.618033           0.431230
# 4           0.603189           0.290479           0.612931           0.431026
# 5           0.512608           0.284928           0.514264           0.388246
# 6           0.165690           0.119349           0.186933           0.158147
#
#    split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 0           0.433019           0.433431           0.684984         0.462293
# 1           0.424759           0.429484           0.680912         0.462910
# 2           0.429605           0.429564           0.671820         0.463476
# 3           0.441788           0.431968           0.662466         0.463324
# 4           0.452371           0.433405           0.653320         0.462193
# 5           0.484448           0.396502           0.525132         0.405417
# 6           0.203748           0.153627           0.189440         0.140733
#
#    std_test_score  rank_test_score
# 0        0.145848                4
# 1        0.141446                3
# 2        0.136327                1
# 3        0.132681                2
# 4        0.129781                5
# 5        0.108385                6
# 6        0.077298                7

# %%
import multiprocessing as mp
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

iris = load_iris()
param_grid = [{ 'penalty':['l1','l2']
                 ,'C': [1.5, 2.0, 2.5, 3.0] }]
gs = GridSearchCV(estimator=LogisticRegression(), param_grid=param_grid, scoring='accuracy', cv=10, n_jobs=mp.cpu_count())
result = gs.fit(iris.data, iris.target)

print("최적 점수 : {}".format(result.best_score_))
print("최적 파라미터 : {}".format(result.best_params_))
print(gs.best_estimator_)
pd.DataFrame(result.cv_results_)
# Out:
# 최적 점수 : 0.9800000000000001
# 최적 파라미터 : {'C': 2.5, 'penalty': 'l2'}
# LogisticRegression(C=2.5)
# c:\bda-test\venv\lib\site-packages\sklearn\model_selection\_search.py:921: UserWarning: One or more of the test scores are non-finite: [       nan 0.97333333        nan 0.97333333        nan 0.98
#         nan 0.98      ]
#   category=UserWarning
# c:\bda-test\venv\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.000000      0.000000           0.0000        0.000000     1.5
# 1       0.020805      0.001991           0.0001        0.000300     1.5
# 2       0.000100      0.000300           0.0000        0.000000       2
# 3       0.021805      0.003545           0.0003        0.000459       2
# 4       0.000200      0.000400           0.0000        0.000000     2.5
# 5       0.022161      0.004194           0.0002        0.000400     2.5
# 6       0.000100      0.000300           0.0000        0.000000       3
# 7       0.026506      0.011769           0.0003        0.000458       3
#
#   param_penalty                       params  split0_test_score  \
# 0            l1  {'C': 1.5, 'penalty': 'l1'}                NaN
# 1            l2  {'C': 1.5, 'penalty': 'l2'}                1.0
# 2            l1  {'C': 2.0, 'penalty': 'l1'}                NaN
# 3            l2  {'C': 2.0, 'penalty': 'l2'}                1.0
# 4            l1  {'C': 2.5, 'penalty': 'l1'}                NaN
# 5            l2  {'C': 2.5, 'penalty': 'l2'}                1.0
# 6            l1  {'C': 3.0, 'penalty': 'l1'}                NaN
# 7            l2  {'C': 3.0, 'penalty': 'l2'}                1.0
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1           0.933333                1.0                1.0           0.933333
# 2                NaN                NaN                NaN                NaN
# 3           0.933333                1.0                1.0           0.933333
# 4                NaN                NaN                NaN                NaN
# 5           0.933333                1.0                1.0           0.933333
# 6                NaN                NaN                NaN                NaN
# 7           0.933333                1.0                1.0           0.933333
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0                NaN                NaN                NaN                NaN
# 1           0.933333           0.933333                1.0                1.0
# 2                NaN                NaN                NaN                NaN
# 3           0.933333           0.933333                1.0                1.0
# 4                NaN                NaN                NaN                NaN
# 5           1.000000           0.933333                1.0                1.0
# 6                NaN                NaN                NaN                NaN
# 7           1.000000           0.933333                1.0                1.0
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0                NaN              NaN             NaN                5
# 1                1.0         0.973333        0.032660                3
# 2                NaN              NaN             NaN                6
# 3                1.0         0.973333        0.032660                3
# 4                NaN              NaN             NaN                7
# 5                1.0         0.980000        0.030551                1
# 6                NaN              NaN             NaN                8
# 7                1.0         0.980000        0.030551                1
